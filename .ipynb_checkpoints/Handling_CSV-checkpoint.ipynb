# %%
import csv

data = [['Name', 'Age', 'City'],
        ['sharib', '20', 'HYD'],
        ['Fateh', '20', 'HYD']
       ]

with open('input_file.csv', mode='w' ) as file:
    csv_writer = csv.writer(file)

    csv_writer.writerows(data)
