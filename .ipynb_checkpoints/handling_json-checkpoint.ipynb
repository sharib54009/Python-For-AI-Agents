# %%
import json

with open('data.json', 'r') as file:
    data = json.load(file)

print(data['employees'])

data['Employees'].append({'name': 'jane deo', 'age':30})

with open('data.json', 'w') as file:
    json.dump(data, file, indent = 4)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 4
#       1 import json
#       3 with open('data.json', 'r') as file:
# ----> 4     data = json.load(file)
#       6 print(data['employees'])
#       8 data['Employees'].append({'name': 'jane deo', 'age':30})
#
# File D:\Installations\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...
