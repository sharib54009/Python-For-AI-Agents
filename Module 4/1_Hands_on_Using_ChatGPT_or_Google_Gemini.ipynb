# %% [markdown]
# # Using ChatGPT or Google Gemini with Python for real-world tasks using thier APIs

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.37.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in D:\Installations\Lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\Installations\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Installations\Lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in D:\Installations\Lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in D:\Installations\Lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in D:\Installations\Lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\Lenova\AppData\Roaming\Python\Python313\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\Lenova\AppData\Roaming\Python\Python313\site-packages (from anyio<5,>=3.5.0->openai) (3.15)
# Requirement already satisfied: certifi in C:\Users\Lenova\AppData\Roaming\Python\Python313\site-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in D:\Installations\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\Installations\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Installations\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\Installations\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Installations\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\Lenova\AppData\Roaming\Python\Python313\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.37.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.7 MB/s  0:00:00
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Installing collected packages: jiter, openai
#
#    ---------------------------------------- 0/2 [jiter]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.14.0 openai-2.37.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Optional: Install Google Gemini
#
# Google Gemini API is free (till now). You can get a key [here](https://aistudio.google.com/app/apikey), just need to sign in with your google account. Gemini may not be available fully in EU.

# %%
 pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load OpenAI API Credentials

# %%
from getpass import getpass

openai_key = getpass("Enter your OpenAI API Key: ")
# Out:
# Enter your OpenAI API Key:  ········

# %%
import openai
from IPython.display import HTML

openai.api_key = openai_key

# %% [markdown]
# ## Load Gemini API credentials
#
# Run this section only if you are using Google Gemini

# %%
from getpass import getpass

gemini_key = getpass("Enter your Gemini API Key: ")
# Out:
# Enter your Gemini API Key:  ········

# %%
import google.generativeai as genai

GOOGLE_API_KEY = gemini_key
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Create ChatGPT and Google Gemini Chat Completion Access Function
#
# This function will use the [Chat Completion API](https://platform.openai.com/docs/api-reference/chat/create) to access ChatGPT for us and return responses
#
# We also add the capability to access the [Google Gemini API](https://ai.google.dev/tutorials/python_quickstart) if you want to use Gemini Pro instead of ChatGPT

# %%
def get_completion(prompt, model="gpt-4o"):
  if model == "gpt-4o":
    messages = [{"role": "user", "content": prompt}]
    response = openai.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0.1, # degree of randomness of the model's output
    )
    return response.choices[0].message.content
      
  if model == 'gemini-2.5-pro':
    model = genai.GenerativeModel('gemini-2.5-pro')
    response = model.generate_content(prompt)
    return response.text
  else:
    return "LLM not configured! Please configure logic for specific model in get_completion()"

# %% [markdown]
# ## Exercise-1: Text Generation with both ChatGPT and Google Gemini
# - Get ChatGPT to generate text by asking it to write a story

# %%
response = get_completion("Write a short story about a college student.")
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = get_completion("Write a short story about a college student.")
#       2 print(response)
#
# Cell In[1], line 4, in get_completion(prompt, model)
#       2 if model == "gpt-4o":
#       3   messages = [{"role": "user", "content": prompt}]
# ----> 4   response = openai.chat.completions.create(
#       5       model=model,
#       6       messages=messages,
#       7       temperature=0.1, # degree of randomness of the model's output
#       8   )
#       9   return response.choices[0].message.content
#      11 if model == 'gemini-2.5-pro':
#
# NameError: name 'openai' is not defined

# %%
# with Gemini
response = get_completion("Write a short story about a college student.", model='gemini-2.5-pro')
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # with Gemini
# ----> 2 response = get_completion("Write a short story about a college student.", model='gemini-2.5-pro')
#       3 print(response)
#
# Cell In[7], line 12, in get_completion(prompt, model)
#       9   return response.choices[0].message.content
#      11 if model == 'gemini-2.5-pro':
# ---> 12   model = genai.GenerativeModel('gemini-2.5-pro')
#      13   response = model.generate_content(prompt)
#      14   return response.text
#
# NameError: name 'genai' is not defined

# %% [markdown]
# ## Exercise-2: Let's try out Zero Shot Prompting!
#
# - Let's get the model to answer the question about Generative AI

# %%
from IPython.display import display, Markdown

# %%
response = get_completion(prompt='Explain Generative AI in 2 bullet points')
display(Markdown(response))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = get_completion(prompt='Explain Generative AI in 2 bullet points')
#       2 display(Markdown(response))
#
# Cell In[1], line 4, in get_completion(prompt, model)
#       2 if model == "gpt-4o":
#       3   messages = [{"role": "user", "content": prompt}]
# ----> 4   response = openai.chat.completions.create(
#       5       model=model,
#       6       messages=messages,
#       7       temperature=0.1, # degree of randomness of the model's output
#       8   )
#       9   return response.choices[0].message.content
#      11 if model == 'gemini-2.5-pro':
#
# NameError: name 'openai' is not defined

# %%
# with Gemini
response = get_completion(prompt='Explain Generative AI in 2 bullet points',
                          model='gemini-2.5-pro')
display(Markdown(response))
# Out:
# - Generative AI is a type of AI that can create new data or content from scratch, such as generating images, text, or music.
# - Generative AI uses machine learning algorithms to learn the patterns and structures of data, and then uses this knowledge to create new data that is similar to the original data.
